# %%
from twitterscraper import query_tweets
import pandas as pd
import datetime as dt
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 6.1; x64; fr; rv:1.9.2.13) Gecko/20101203 Firebird/3.6.13'}

# %%
begin_date = dt.date(2020,1,1)
end_date = dt.date(2020,5,26)
limit=30000
lang = 'english'

# %%
tweets = query_tweets("#metoo",begindate=begin_date,enddate=end_date,limit=limit,lang=lang)
# Out:
# INFO: queries: ['#metoo since:2020-01-01 until:2020-01-08', '#metoo since:2020-01-08 until:2020-01-15', '#metoo since:2020-01-15 until:2020-01-22', '#metoo since:2020-01-22 until:2020-01-30', '#metoo since:2020-01-30 until:2020-02-06', '#metoo since:2020-02-06 until:2020-02-13', '#metoo since:2020-02-13 until:2020-02-21', '#metoo since:2020-02-21 until:2020-02-28', '#metoo since:2020-02-28 until:2020-03-06', '#metoo since:2020-03-06 until:2020-03-14', '#metoo since:2020-03-14 until:2020-03-21', '#metoo since:2020-03-21 until:2020-03-28', '#metoo since:2020-03-28 until:2020-04-04', '#metoo since:2020-04-04 until:2020-04-12', '#metoo since:2020-04-12 until:2020-04-19', '#metoo since:2020-04-19 until:2020-04-26', '#metoo since:2020-04-26 until:2020-05-04', '#metoo since:2020-05-04 until:2020-05-11', '#metoo since:2020-05-11 until:2020-05-18', '#metoo since:2020-05-18 until:2020-05-26']
# INFO: Got 842 tweets (842 new).
# INFO: Got 1570 tweets (728 new).
# ...

# %%
df = pd.DataFrame(t.__dict__ for t in tweets)

# %%
df.head()
# Out:
#        screen_name                 username              user_id  \
# 0      RealEAJones            Obama's Waifu  1138597703955439617
# 1      ericsalinas  éric #Día75 en casa 💜✝️             55698373
# 2          VICD420            Vic DeMoto 🌹🔥            118954884
# 3    BaresiUmberto           Umberto Baresi  1234714762287542272
# 4  GaetanoPasqual2           CornpopStevens  1243739042228903936
#
#               tweet_id                                    tweet_url  \
# 0  1246225682407006208      /RealEAJones/status/1246225682407006208
# 1  1246225623321845762      /ericsalinas/status/1246225623321845762
# 2  1246225485870198789          /VICD420/status/1246225485870198789
# 3  1246225451132915713    /BaresiUmberto/status/1246225451132915713
# 4  1246225123566387200  /GaetanoPasqual2/status/1246225123566387200
#
#             timestamp  timestamp_epochs  \
# 0 2020-04-03 23:58:51        1585958331
# 1 2020-04-03 23:58:37        1585958317
# ...

# %%
df.to_csv('#metoo_twitter.csv')
