# %%
print('hello')
# Out:
# hello

# %%
import twitterscraper as ts
import pandas as pd

# %%
tweets = ts.query.query_tweets_from_user('IndiaMeToo')
# Out:
# INFO: Scraping tweets from https://twitter.com/IndiaMeToo
# INFO: Using proxy 191.102.74.197:999
# INFO: Scraping tweets from https://twitter.com/i/profiles/show/IndiaMeToo/timeline/tweets?include_available_features=1&include_entities=1&max_position=1258309315904991232&reset_error_state=false
# INFO: Using proxy 36.80.126.97:8080
# INFO: Scraping tweets from https://twitter.com/i/profiles/show/IndiaMeToo/timeline/tweets?include_available_features=1&include_entities=1&max_position=1257666513584128000&reset_error_state=false
# INFO: Using proxy 36.90.119.52:8080
# INFO: Scraping tweets from https://twitter.com/i/profiles/show/IndiaMeToo/timeline/tweets?include_available_features=1&include_entities=1&max_position=1257647135010349057&reset_error_state=false
# INFO: Using proxy 36.75.76.126:3128
# ...

# %%
df = pd.DataFrame(t.__dict__ for t in tweets)

# %%
df
# Out:
#        screen_name        username              user_id             tweet_id  \
# 0       IndiaMeToo     #MeTooIndia  1049246784126636032  1066921296129417216
# 1       IndiaMeToo     #MeTooIndia  1049246784126636032  1263416951457509376
# 2        SayftyCom      Sayfty.com           1266038659  1257364869042638850
# 3       IndiaMeToo     #MeTooIndia  1049246784126636032  1260935632169234434
# 4    RajivLakshman  Rajiv Lakshman            354327725  1259855468652093443
# ..             ...             ...                  ...                  ...
# 599    thirunangai      GRACE BANU            978410575  1201457534298546177
# 600     IndiaMeToo     #MeTooIndia  1049246784126636032  1201478871763177473
# 601     IndiaMeToo     #MeTooIndia  1049246784126636032  1201478494968004610
# 602   santosht2028       Santosh t           2617061156  1201473816473395200
# 603     IndiaMeToo     #MeTooIndia  1049246784126636032  1201477291940962304
#
# ...

# %%
df.to_csv('MeTooIndia.csv')
