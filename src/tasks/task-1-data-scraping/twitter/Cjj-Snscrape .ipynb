# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
def search_by_keywords(keywords, start, end, tweet_limit):
    '''
    This is to search for tweets based on keywords, with location preset to Singapore. 
    Keywords: can be string or list 
    Date format: YYYY-MM-DD
    '''
    loc = '1.290270, 103.851959, 30km'
    scraped_tweets = sntwitter.TwitterSearchScraper(f'{keywords} geocode:"{loc}" since:{start} until:{end}').get_items()
    sliced_scraped_tweets = itertools.islice(scraped_tweets, tweet_limit)
    tweets_df = pd.DataFrame(sliced_scraped_tweets) #[['date', 'content']]
    tweets_df.to_csv("snscrape-test3.csv")
    return tweets_df


search_by_keywords(keywords = '[covid19]', start = '2020-1-1', end='2020-12-21', tweet_limit= 10000)
# Returned around 4.3k rows of data
# Out:
#                                                     url  \
# 0     https://twitter.com/pmrutcjohor/status/1340488...
# 1     https://twitter.com/DrMLChua/status/1340477359...
# 2     https://twitter.com/KradoTheLion/status/134034...
# 3     https://twitter.com/humaspolsekmgys/status/134...
# 4     https://twitter.com/edoraebrahem/status/133995...
# ...                                                 ...
# 4389  https://twitter.com/velorunsdeworld/status/122...
# 4390  https://twitter.com/septian/status/12275817484...
# 4391  https://twitter.com/WayneGKline/status/1227565...
# 4392  https://twitter.com/leejanhau/status/122742511...
# 4393  https://twitter.com/adrianivy13/status/1227394...
#
#                           date  \
# 0    2020-12-20 02:47:33+00:00
# 1    2020-12-20 02:01:22+00:00
# 2    2020-12-19 17:16:38+00:00
# 3    2020-12-19 09:13:08+00:00
# 4    2020-12-18 15:14:05+00:00
# ...                        ...
# 4389 2020-02-12 13:22:35+00:00
# ...
