# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools


def search_by_keywords(keyword, start, end, tweet_limit, file_name, year):
    '''
    This is to search for tweets based on keywords, with location preset to Singapore. 
    Keywords: can be string or list 
    Date format: YYYY-MM-DD
    '''
    loc = '1.290270, 103.851959, 20km'
    scraped_tweets = sntwitter.TwitterSearchScraper(f'{keyword} geocode:"{loc}" since:{start} until:{end}').get_items()
    sliced_scraped_tweets = itertools.islice(scraped_tweets, tweet_limit)
    tweets_df = pd.DataFrame(sliced_scraped_tweets) #[['date', 'content']]
    tweets_df.to_csv(f'Twitter{keyword}{year}.csv')
    return tweets_df

# %%
hashtag = ["#HereForYou", "#depression", "#selfcare", "#selflove", "#mentalillness", "#therapy", "#MentalHealthAwareness"
           , "#AnxietyAwareness", "#ItsOkayNotToBeOkay", "#EndTheStigmaofMentalHealth", "#ptsd", "#stress", "#trauma", "#selfcare4sg",
           "#ShiftYourMindset", "#mentalhealthmatters", "#selfgrowth", "#anxiety", "#covid19", "#insomnia", "#love", "#pandemic", "#support", "#MentalHealthAdvocate"]

# %%
for i in hashtag:
    search_by_keywords(i, start = '2020-1-1', end='2020-12-31', tweet_limit=10000, file_name = i, year = 2020)

# %%
for i in hashtag:
    search_by_keywords(i, start = '2021-1-1', end='2021-07-10', tweet_limit=10000, file_name = i, year = 2021)

# %%
cd Downloads/tweets2020-2021/2020
# Out:
# /Users/valencialie/Downloads/tweets2020-2021/2020

# %%
import os, glob
import pandas as pd

path = "/Users/valencialie/Downloads/tweets2020-2021/2020"

all_files = glob.glob(os.path.join(path, "*.csv"))

all_df = []
for f in all_files:
    df = pd.read_csv(f, sep=',')
    df['file'] = f.split('/')[-1]
    all_df.append(df)
    
merged_df = pd.concat(all_df, ignore_index=True, sort=True)

# %%
import os, glob
import pandas as pd

path = "/Users/valencialie/Downloads/tweets2020-2021/2021"

all_files = glob.glob(os.path.join(path, "*.csv"))

all_df = []
for f in all_files:
    df = pd.read_csv(f, sep=',')
    df['file'] = f.split('/')[-1]
    all_df.append(df)
    
merged_df1 = pd.concat(all_df, ignore_index=True, sort=True)

# %%
merged_df
# Out:
#      Unnamed: 0 cashtags                                            content  \
# 0             0      NaN  It may not be easy but remember; there is no s...
# 1             1      NaN  💚𝙑𝙤𝙡𝙪𝙣𝙩𝙚𝙚𝙧 𝙬𝙞𝙩𝙝 𝙍𝙚:𝙈𝙞𝙣𝙙 💚\n\nApplications for ...
# 2             2      NaN  There are actually 100 trillion ways which you...
# 3             3      NaN  💆🏿‍♂️🌸𝙎𝙚𝙡𝙛-𝙘𝙖𝙧𝙚 🌸🙆🏼\n\nThe term self-care is u...
# 4             4      NaN  We want to hear from you too! What are you gra...
# ...         ...      ...                                                ...
# 4189          4      NaN  "Knowing others is intelligence;\nknowing your...
# 4190          5      NaN  There are 2 words in this tattoo! \nMake a gue...
# 4191          6      NaN  Happy Valentine's Day to all of you and your l...
# 4192          7      NaN  Little Butterfly wishes everyone a Prosperous ...
# 4193          8      NaN  First workshop of the year! Full house with 2 ...
#
# ...

# %%
merged_df1
# Out:
#      Unnamed: 0 cashtags                                            content  \
# 0             0      NaN  Spending lots of effort just to get through a ...
# 1             1      NaN  A helpful article on how and why you should ma...
# 2             2      NaN  Deep breathing has often been proven to be ver...
# 3             3      NaN  It’s Friday! 🥳 Remember to spend some time wit...
# 4             4      NaN  "I need to tell my brain that, “Yes, you’re ex...
# ...         ...      ...                                                ...
# 1644        142      NaN  Morning mantra! #believe #womanquotes  #mirror...
# 1645        143      NaN  Greeting Cards, Anniversary Cards, Valentine's...
# 1646        144      NaN  Greeting Card l, Anniversary Card, Valentine's...
# 1647        145      NaN  Still working in the industry I truly #love so...
# 1648        146      NaN  Praying all our family and friends a healthy, ...
#
# ...

# %%
def combining(data, year):
    data.file = data.file.str.split("#").str[1]
    data.file = data.file.str.split(".").str[0]
    data.file = data.file.str.replace(f'{year}', '')

# %%
combining(merged_df, 2020)

# %%
combining(merged_df1, 2021)

# %%
merged_df = merged_df.rename(columns = {'file' : 'query'})

# %%
merged_df1 = merged_df1.rename(columns = {'file' : 'query'})

# %%
merged_df.to_csv("hashtags2020.csv")

# %%
merged_df1.to_csv("hashtags2021.csv")
