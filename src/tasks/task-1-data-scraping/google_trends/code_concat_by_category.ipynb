# %% [markdown]
# # Note:
# Due to Google Trends blocking scraping with a for loop, the list has been broken down into 3 items (or columns from a dataframe) at a time.

# %%
import pandas as pd
import datetime      
from pytrends.request import TrendReq
import time

# %%
df = pd.read_csv('google_trend_keyword.csv')
output_path = '../../../data/google_trends/'

# %%
df.head(50)
# Out:
#             general_terms                       diagnosis        emotions  \
# 0          mental illness                      depression         unalive
# 1           mental health                        neurosis            help
# 2               self-harm  post traumatic stress disorder            dead
# 3                 suicide                   mood disorder   no motivation
# 4                   death                     melancholia      loneliness
# 5                 therapy                       dysthymia          lonely
# 6              counsellor                         bipolar        isolated
# 7             counselling                       insomnia           stress
# 8                  trauma                             NaN           angst
# 9                  phobia                             NaN         emotion
# 10              addiction                             NaN  social anxiety
# 11                 stigma                             NaN     mood swings
# 12                  abuse                             NaN           tired
# 13               disorder                             NaN         trapped
# 14             dependence                             NaN        paranoia
# 15              socialize                             NaN     overwhelmed
# 16          psychologist                              NaN       irritable
# 17             well-being                             NaN    weighed down
# 18            self-esteem                             NaN             NaN
# 19                  toxic                             NaN             NaN
# 20                  drugs                             NaN             NaN
# 21     depression hotline                             NaN             NaN
# 22  mental health hotline                             NaN             NaN
# 23                hotline                             NaN             NaN
# 24     emotional support                              NaN             NaN
# 25  psychological support                             NaN             NaN
#
#                                                  ngos       general terms  \
# 0                          Institute of Mental Health            covid-19
# 1                                                 IMH            epidemic
# 2                             Samaritans Of Singapore            pandemic
# 3                                                 SOS           pre-covid
# 4                               National Care Hotline         coronavirus
# 5                Fei Yue’s Online Counselling Service             vaccine
# 6                             Silver Ribbon Singapore      clinical trial
# 7   Community Psychology Hub’s Online Counselling ...     contact tracing
# 8         Big Love Child Protection Specialist Centre         contactless
# 9   HEART @ Fei Yue Child Protection Specialist Ce...                mask
# 10  PAVE Integrated Services for Individual and Fa...        asymptomatic
# 11                                      Project StART  national emergency
# 12                                  TRANS SAFE Centre        transmission
# 13                            TOUCHline (Counselling)            hospital
# 14                    Youth Mental Well-Being Network  healthcare worker
# 15                                        Care Corner         symptomatic
# 16                                                NaN            symptoms
# 17                                                NaN            outbreak
# 18                                                NaN              spread
# 19                                                NaN             hygiene
# 20                                                NaN              crisis
# 21                                                NaN          new normal
# 22                                                NaN                zoom
# 23                                                NaN           frontline
# 24                                                NaN                 NaN
# 25                                                NaN                 NaN
#
#                measures              impacts
# 0           restriction          uncertainty
# 1     social distancing                death
# 2       circuit breaker      community cases
# 3            quarantine        fatality rate
# 4              lockdown              cluster
# 5                   wfh         retrenchment
# 6      tighter measures              variant
# 7               phase 2     Stay Home Notice
# 8             screening                  shn
# 9               testing  home based learning
# 10            isolation                  hbl
# 11      safe distancing       school closure
# 12  physical distancing       job insecurity
# 13     stay home notice                  NaN
# 14     heightened alert                  NaN
# 15           safe entry                  NaN
# 16                  NaN                  NaN
# 17                  NaN                  NaN
# 18                  NaN                  NaN
# 19                  NaN                  NaN
# 20                  NaN                  NaN
# 21                  NaN                  NaN
# 22                  NaN                  NaN
# 23                  NaN                  NaN
# 24                  NaN                  NaN
# 25                  NaN                  NaN

# %%
for col in df.columns:
    print(f'Projected shape of the {col} column is {df[col].dropna().shape}')
# Out:
# Projected shape of the general_terms column is (26,)
# Projected shape of the diagnosis column is (8,)
# Projected shape of the emotions column is (18,)
# Projected shape of the ngos column is (16,)
# Projected shape of the general terms column is (24,)
# Projected shape of the measures column is (16,)
# Projected shape of the impacts column is (13,)

# %%
# Highly recommended that you scrape 3 columns at a time as Google Trends will time you out
startTime = time.time()
pytrend = TrendReq(hl='en-US') # language of the query

category_list_1 = ['general_terms',
                 'diagnosis',
                 'emotions']

category_list_2 = ['ngos',
                   'general terms',
                   'measures']

category_list_3 = ['impacts']

def google_trends_scraper(category_list, df): # pass in the original df with the shorter list (max 3)
    filtered_df = df.loc[:,category_list]

    for idx, category in enumerate(category_list):
        colnames = category_list[idx]
        list_temp = filtered_df.iloc[:,idx].dropna().to_list()
        
        extracted_data = []

        for i in range(0,len(list_temp)):
            keywords = [list_temp[i]]
            pytrend.build_payload(
            kw_list=keywords,
            cat=0, # to specify what of google trend you want to search (images? news?)
            timeframe='2019-01-01 2021-07-07', # date range of what you want
            geo='SG') # what country you want to pull the data from
            data = pytrend.interest_over_time()
            if not data.empty:
                data = data.drop(labels=['isPartial'],axis='columns')
            extracted_data.append(data)

        result = pd.concat(extracted_data, axis=1)
        
        missing_keywords = set(list_temp).difference(result.columns.to_list())
        
        if missing_keywords == set():
            print(f"All keywords under the '{category}' category has valid data")
        else:
            print(missing_keywords)
            
        result.to_csv(f'{output_path}{category}.csv')

#         executionTime = (time.time() - startTime)
#         print('Execution time in sec.: ' + str(executionTime))

# %% [markdown]
# # Load one cell at a time and wait for a couple seconds when the previous cell is done
# Do not press all cells at a go. Google may deny your request

# %%
google_trends_scraper(category_list_1, df)
# Out:
# {'psychological support'}
# All keywords under the 'diagnosis'category has valid data
# {'weighed down', 'unalive'}

# %%
google_trends_scraper(category_list_2, df)
# Out:
# {'TOUCHline (Counselling)', 'Big Love Child Protection Specialist Centre', 'PAVE Integrated Services for Individual and Family Protection', 'Youth Mental Well-Being Network', 'HEART @ Fei Yue Child Protection Specialist Centre', 'Fei Yue’s Online Counselling Service', 'Community Psychology Hub’s Online Counselling platform'}
# All keywords under the 'general terms'category has valid data
# All keywords under the 'measures'category has valid data

# %%
google_trends_scraper(category_list_3, df)
# Out:
# {'job insecurity'}
