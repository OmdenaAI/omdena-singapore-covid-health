# %%
import pandas as pd
import urllib.request,sys,time
from bs4 import BeautifulSoup
import requests
import csv

# %%
df = pd.read_csv('cna_urls_combined.csv')
df
# Out:
#      Page                                                URL
# 0       0  https://www.channelnewsasia.com/news/singapore...
# 1       0  https://www.channelnewsasia.com/news/sport/ten...
# 2       0  https://www.channelnewsasia.com/news/singapore...
# 3       0  https://www.channelnewsasia.com/news/lifestyle...
# 4       0  https://www.channelnewsasia.com/news/singapore...
# ..    ...                                                ...
# 230    23  https://www.channelnewsasia.com/news/cnainside...
# 231    23  https://www.channelnewsasia.com/news/commentar...
# 232    23  https://www.channelnewsasia.com/news/commentar...
# 233    23  https://www.channelnewsasia.com/news/cnainside...
# 234    23  https://www.channelnewsasia.com/news/commentar...
#
# [235 rows x 2 columns]

# %%
# title, url, date, text, covid (TRUE/FALSE values) comments (if any), tags

def get_title(soup):
    title = soup.find('title').text
    return title

def get_date(soup):
    if len(soup.select('time.article__details-item')) == 0:
        article_date = soup.select("time.video-stage__details-item")[0].text
    else:
        article_date = soup.select('time.article__details-item')[0].text
    date = pd.to_datetime(article_date, infer_datetime_format=True).strftime("%d/%m/%Y")
    return date
        
def get_text(soup):
    text = ''
    article = soup.find("div", attrs={"class": "c-rte--article"})
    if article ==  None:
        article = soup.find("div", attrs={"class": "c-rte--light"})
    articleParagraph = article.find_all("p")
    for i in range(len(articleParagraph)):
#             print(articleParagraph[i].text)
        text += articleParagraph[i].text + '\n'
    return text

def get_tags(soup):
    tags_list = []
    if len(soup.findAll('ul', attrs={'class':"link-list__list"})) == 1:
        tags = soup.findAll('a', attrs={'class':"link-list__link text-white"})
        for tag in tags:
            tags_list.append(tag.text)
    else:
        tags = soup.findAll('ul', attrs={'class':"link-list__list"})[1]
        for tag in tags.find_all("a"):
            tags_list.append(tag.text)
    return tags_list

def covid_related(title, content):
    covid_related = False
    matches = ['covid-19','pandemic','restriction','social distancing','circuit breaker','pre-covid','coronavirus','quarantine','lockdown','wfh']
    if any(x in title.lower() for x in matches) or any(x in content.lower() for x in matches):
        covid_related = True
    return covid_related

def sg_related(title, content):
    sg_related = False
    if 'singapore' in title.lower() or 'singapore' in content.lower():
        sg_related = True
    return sg_related

# %%
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}

def get_url_data(url):
    
    url_data = {}
#     print(url)
    
    if 'cna-lifestyle' not in url and 'cna-luxury' not in url:
        
        result = requests.get(url, headers=headers)
        
        if result.status_code != 404:
        
            soup=BeautifulSoup(result.text,'html.parser')

            title = get_title(soup)
            url_data['title'] = title

            url_data['date'] = get_date(soup)

            text = get_text(soup)
            url_data['text'] = text
        #     print(text)

            url_data['covid'] = covid_related(title, text)

            url_data['tags'] = get_tags(soup)

            url_data['sg'] = sg_related(title, text)
    
#     print(url_data)
    return url_data

# %%
df['data'] = df.apply(lambda x: get_url_data(x['URL']), axis=1)

df_backup = df.copy()

df = df.join(pd.DataFrame(df.pop('data').values.tolist()))

df
# Out:
#      Page                                                URL  \
# 0       0  https://www.channelnewsasia.com/news/singapore...
# 1       0  https://www.channelnewsasia.com/news/sport/ten...
# 2       0  https://www.channelnewsasia.com/news/singapore...
# 3       0  https://www.channelnewsasia.com/news/lifestyle...
# 4       0  https://www.channelnewsasia.com/news/singapore...
# ..    ...                                                ...
# 230    23  https://www.channelnewsasia.com/news/cnainside...
# 231    23  https://www.channelnewsasia.com/news/commentar...
# 232    23  https://www.channelnewsasia.com/news/commentar...
# 233    23  https://www.channelnewsasia.com/news/cnainside...
# 234    23  https://www.channelnewsasia.com/news/commentar...
#
#                                                  title        date  \
# 0    ‘Mental health is everyone’s business’: How so...  09/07/2021
# 1    Tennis-'Athletes are humans': Osaka stands by ...  08/07/2021
# 2    Suicide cases in Singapore highest in 8 years ...  08/07/2021
# 3    The number of young children who need mental h...  03/07/2021
# 4    AI in mental health screening: System enables ...  30/06/2021
# ..                                                 ...         ...
# 230  In a mental ward for nearly 35 years, he paint...  15/07/2018
# 231  Commentary: We still fail to understand that s...  08/07/2018
# 232  Commentary: Schizophrenia, a life increasingly...  09/06/2018
# 233  He’s 48, and already grappling with dementia -...  07/06/2018
# 234  Commentary: Living with bipolar disorder, trud...  30/03/2018
#
#                                                   text  covid  \
# 0    SINGAPORE: Amid a rapidly ageing society, the ...   True
# 1    REUTERS:     World number two Naomi Osaka said...  False
# 2    SINGAPORE: Singapore reported 452 suicides las...   True
# 3    When Marie, 11, called a suicide prevention ho...   True
# 4    Mental health screening is getting a boost fro...  False
# ..                                                 ...    ...
# 230  SINGAPORE: For nearly 35 years, Mr Sim Kah Lim...  False
# 231  SINGAPORE: Man is an amazing creature. We have...  False
# 232  SINGAPORE: It was a cold night in January. A s...  False
# 233  SINGAPORE: He was once an accomplished teacher...  False
# 234  SINGAPORE: World Bipolar Day falls on Mar 30 e...  False
#
#                                                   tags     sg
# 0                   [COVID-19, elderly, mental health]   True
# 1    [sports, mental health, Japan, French Open, Os...  False
# 2    [suicide, mental health, Samaritans of Singapo...   True
# 3       [Wellness, wellbeing, mental health, children]  False
# 4                                  [mental health, AI]  False
# ..                                                 ...    ...
# 230                  [art, mental health, CNA Insider]   True
# 231  [mental health, bipolar disorder, schizophreni...   True
# 232  [mental health, schizophrenia, IMH, depression...   True
# 233                       [mental health, CNA Insider]   True
# 234      [mental health, bipolar disorder, depression]   True
#
# [235 rows x 8 columns]

# %%
df = df[df.sg == True]
del df['sg']

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106 entries, 0 to 234
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Page    106 non-null    int64
#  1   URL     106 non-null    object
#  2   title   106 non-null    object
#  3   date    106 non-null    object
#  4   text    106 non-null    object
#  5   covid   106 non-null    object
#  6   tags    106 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 6.6+ KB

# %%
df
# Out:
#      Page                                                URL  \
# 0       0  https://www.channelnewsasia.com/news/singapore...
# 2       0  https://www.channelnewsasia.com/news/singapore...
# 7       0  https://www.channelnewsasia.com/news/commentar...
# 9       0  https://www.channelnewsasia.com/news/commentar...
# 10      1  https://www.channelnewsasia.com/news/commentar...
# ..    ...                                                ...
# 230    23  https://www.channelnewsasia.com/news/cnainside...
# 231    23  https://www.channelnewsasia.com/news/commentar...
# 232    23  https://www.channelnewsasia.com/news/commentar...
# 233    23  https://www.channelnewsasia.com/news/cnainside...
# 234    23  https://www.channelnewsasia.com/news/commentar...
#
#                                                  title        date  \
# 0    ‘Mental health is everyone’s business’: How so...  09/07/2021
# 2    Suicide cases in Singapore highest in 8 years ...  08/07/2021
# 7    Commentary: Why some night owls are flourishin...  25/06/2021
# 9    Commentary: Workers appreciate mental health d...  23/06/2021
# 10   Commentary: Revenge bedtime procrastination in...  15/06/2021
# ..                                                 ...         ...
# 230  In a mental ward for nearly 35 years, he paint...  15/07/2018
# 231  Commentary: We still fail to understand that s...  08/07/2018
# 232  Commentary: Schizophrenia, a life increasingly...  09/06/2018
# 233  He’s 48, and already grappling with dementia -...  07/06/2018
# 234  Commentary: Living with bipolar disorder, trud...  30/03/2018
#
#                                                   text  covid  \
# 0    SINGAPORE: Amid a rapidly ageing society, the ...   True
# 2    SINGAPORE: Singapore reported 452 suicides las...   True
# 7    SINGAPORE: To paraphrase Linda Evangelista, th...   True
# 9    SINGAPORE: You may have read about Naomi Osaka...   True
# 10   SINGAPORE: The benefits of good sleep are well...  False
# ..                                                 ...    ...
# 230  SINGAPORE: For nearly 35 years, Mr Sim Kah Lim...  False
# 231  SINGAPORE: Man is an amazing creature. We have...  False
# 232  SINGAPORE: It was a cold night in January. A s...  False
# 233  SINGAPORE: He was once an accomplished teacher...  False
# 234  SINGAPORE: World Bipolar Day falls on Mar 30 e...  False
#
#                                                   tags
# 0                   [COVID-19, elderly, mental health]
# 2    [suicide, mental health, Samaritans of Singapo...
# 7                 [sleep, rest, stress, mental health]
# 9                      [Mental Health, Work, COVID-19]
# 10   [sleep, Netflix, e-devices, mobile phones, str...
# ..                                                 ...
# 230                  [art, mental health, CNA Insider]
# 231  [mental health, bipolar disorder, schizophreni...
# 232  [mental health, schizophrenia, IMH, depression...
# 233                       [mental health, CNA Insider]
# 234      [mental health, bipolar disorder, depression]
#
# [106 rows x 7 columns]

# %%
# df.to_csv('cna_articles.csv', index=False)
